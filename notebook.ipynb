# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [M. Alan Daulay]
# - **Email:** [alandaulay4@gmail.com]
# - **ID Dicoding:** [CDCC223D6Y0280]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# #  Proyek Analisis Data: Bike Sharing Dataset
#
# ##  Latar Belakang
# Dataset ini berisi data penyewaan sepeda yang dipengaruhi oleh faktor waktu, musim, dan kondisi cuaca. Analisis ini bertujuan untuk memahami pola penggunaan sepeda serta memberikan insight yang dapat digunakan untuk pengambilan keputusan bisnis.
#
# ##  Tujuan Analisis
# 1. Mengidentifikasi faktor yang memengaruhi penurunan jumlah penyewaan sepeda.
# 2. Menganalisis pola penggunaan sepeda berdasarkan waktu dan kondisi cuaca.

# %% [markdown]
# #  Pertanyaan Bisnis
#
# ##  Pertanyaan 1
# **Faktor apa saja yang memengaruhi penurunan jumlah penyewaan sepeda (cnt) hingga lebih dari 20% pada musim dingin (winter) tahun 2012 dibanding musim lainnya?**
#
# **Keterangan :**
# - Specific: Fokus pada jumlah penyewaan (cnt), musim winter, tahun 2012
# - Measurable: Penurunan lebih dari 20%
# - Action-oriented: Dapat digunakan untuk strategi peningkatan penggunaan
# - Relevant: Berkaitan langsung dengan performa bisnis
# - Time-bound: Tahun 2012
#
#
# ##  Pertanyaan 2
# **Bagaimana pengaruh kondisi cuaca (weathersit) dan jam (hour) terhadap pola penggunaan sepeda, khususnya pada jam sibuk?**
#
# **Keterangan :**
# - Specific: Fokus pada jam dan kondisi cuaca
# - Measurable: Jumlah penyewaan per jam
# - Action-oriented: Untuk optimasi distribusi sepeda
# - Relevant: Penting untuk operasional
# - Time-bound: Pola harian

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set(style='whitegrid')

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data
# Tahap ini meliputi pengumpulan data, penilaian kualitas data, dan pembersihan data.

# %% [markdown]
# #### Load df ...

# %%
day_df = pd.read_csv('data/day.csv')
hour_df = pd.read_csv('data/hour.csv')

display(day_df.head())
display(hour_df.head())
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data
# Menilai kualitas data untuk menemukan permasalahan.

# %% [markdown]
# #### Identifying ... problem

# %%
print("Missing Values Day Dataset:")
print(day_df.isna().sum())

print("\nMissing Values Hour Dataset:")
print(hour_df.isna().sum())
# Out:
# Missing Values Day Dataset:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
#
# Missing Values Hour Dataset:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Duplicate Day:", day_df.duplicated().sum())
print("Duplicate Hour:", hour_df.duplicated().sum())
# Out:
# Duplicate Day: 0
# Duplicate Hour: 0

# %%
day_df.info()
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Steps to Take:**
# 1. Format kolom tanggal (dteday) masih berupa object
# 2. Terdapat kemungkinan outlier pada jumlah penyewaan (cnt)
# 3. Data numerik masih dalam bentuk normalisasi

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
# Convert datetime
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# Drop duplicate
day_df.drop_duplicates(inplace=True)
hour_df.drop_duplicates(inplace=True)

# Handling outlier sederhana
day_df = day_df[day_df['cnt'] < day_df['cnt'].quantile(0.99)]

day_df.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Analisis ini dilakukan untuk menjawab pertanyaan bisnis.

# %% [markdown]
# ### Explore ...

# %% [markdown]
# 1. EDA UNIVARIATE

# %%
num_cols = ['cnt', 'temp', 'hum', 'windspeed']

for col in num_cols:
    fig, ax = plt.subplots(1,3, figsize=(15,4))

    sns.histplot(day_df[col], kde=True, ax=ax[0])
    ax[0].set_title(f"Histogram {col}")

    sns.boxplot(x=day_df[col], ax=ax[1])
    ax[1].set_title(f"Boxplot {col}")

    stats.probplot(day_df[col], dist="norm", plot=ax[2])
    ax[2].set_title(f"Q-Q Plot {col}")

    plt.show()

# %%
for col in num_cols:
    print(f"{col}")
    print("Skewness:", day_df[col].skew())
    print("Kurtosis:", day_df[col].kurt())
    print("-----")
# Out:
# cnt
# Skewness: -0.07582541557823454
# Kurtosis: -0.8311907114416535
# -----
# temp
# Skewness: -0.037618082630384686
# Kurtosis: -1.1245377304182462
# -----
# hum
# Skewness: -0.07868219718718457
# Kurtosis: -0.06403144241082792
# -----
# windspeed
# Skewness: 0.6820175107588468
# Kurtosis: 0.4149072731667176
# -----

# %% [markdown]
# ### Insight Univariate:
# Distribusi variabel menunjukkan bahwa beberapa fitur seperti `cnt` memiliki distribusi yang cenderung skewed, yang menunjukkan adanya ketidakseimbangan data.
#
# Boxplot menunjukkan adanya outlier pada beberapa variabel, terutama pada jumlah penyewaan (cnt).

# %% [markdown]
# 2. EDA MULTIVARIATE

# %%
plt.figure(figsize=(10,6))
sns.heatmap(day_df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
sns.lmplot(data=day_df, x='temp', y='cnt', line_kws={'color':'red'})
plt.title("Hubungan Temperatur vs Penyewaan")
plt.show()

# %%
sns.pairplot(day_df[['cnt','temp','hum','windspeed']])
plt.show()

# %% [markdown]
# ### Insight Multivariate:
# Terdapat korelasi positif antara temperatur dan jumlah penyewaan sepeda. Hal ini menunjukkan bahwa cuaca yang lebih hangat meningkatkan penggunaan sepeda.
#
# Sebaliknya, kelembaban dan kecepatan angin memiliki hubungan negatif terhadap jumlah penyewaan.

# %% [markdown]
# # 3. EDA NUMERIKAL

# %% [markdown]
# PERCENTILE

# %%
day_df.describe(percentiles=[0.05,0.1,0.9,0.95])
# Out:
#           instant                         dteday      season          yr  \
# count  723.000000                            723  723.000000  723.000000
# mean   363.596127  2011-12-29 14:18:25.394190848    2.492393    0.495159
# min      1.000000            2011-01-01 00:00:00    1.000000    0.000000
# 5%      37.100000            2011-02-06 02:24:00    1.000000    0.000000
# 10%     73.200000            2011-03-14 04:48:00    1.000000    0.000000
# 50%    362.000000            2011-12-28 00:00:00    2.000000    0.000000
# 90%    658.800000            2012-10-19 19:12:00    4.000000    1.000000
# 95%    694.900000            2012-11-24 21:36:00    4.000000    1.000000
# max    731.000000            2012-12-31 00:00:00    4.000000    1.000000
# std    210.969265                            NaN    1.114441    0.500323
#
#             mnth     holiday     weekday  workingday  weathersit        temp  \
# count  723.00000  723.000000  723.000000  723.000000  723.000000  723.000000
# ...

# %% [markdown]
# NORMALITY TEST (SHAPIRO)

# %%
from scipy.stats import shapiro

stat, p = shapiro(day_df['cnt'].sample(500))
print("p-value:", p)
# Out:
# p-value: 1.1926601099801665e-06

# %% [markdown]
# VARIANSI & STD

# %%
day_df.groupby('season')['cnt'].agg(['mean','std','var'])
# Out:
#                mean          std           var
# season
# 1       2604.132597  1399.942119  1.959838e+06
# 2       4955.675824  1668.475623  2.783811e+06
# 3       5570.781421  1408.555119  1.984028e+06
# 4       4706.542373  1679.710253  2.821427e+06

# %% [markdown]
# ### Insight Numerikal:
# Distribusi data tidak sepenuhnya normal berdasarkan uji Shapiro-Wilk.
#
# Variansi antar musim menunjukkan bahwa fluktuasi penggunaan sepeda berbeda pada setiap musim.

# %% [markdown]
# # 4. EDA KATEGORIKAL

# %% [markdown]
# COUNTPLOT

# %%
sns.countplot(x='season', data=day_df)
plt.title("Distribusi Musim")
plt.show()

# %% [markdown]
# BOXPLOT PER KATEGORI

# %%
sns.boxplot(x='season', y='cnt', data=day_df)
plt.title("Distribusi Penyewaan per Musim")
plt.show()

# %% [markdown]
# CHI-SQUARE TEST

# %%
from scipy.stats import chi2_contingency

contingency = pd.crosstab(day_df['season'], day_df['weathersit'])
chi2, p, dof, ex = chi2_contingency(contingency)

print("p-value:", p)
# Out:
# p-value: 0.033464001656433484

# %% [markdown]
# ### Insight Kategorikal:
# Distribusi kategori menunjukkan bahwa musim memiliki pengaruh signifikan terhadap jumlah penyewaan.
#
# Hasil uji Chi-Square menunjukkan adanya hubungan antara musim dan kondisi cuaca.

# %% [markdown]
# ## Visualization & Explanatory Analysis
# Visualisasi digunakan untuk memperjelas hasil analisis.

# %% [markdown]
# ### Pertanyaan 1:

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='season', y='cnt', data=day_df, palette='coolwarm')

plt.title("Rata-rata Penyewaan Sepeda Berdasarkan Musim", fontsize=14)
plt.xlabel("Season (1=Spring, 2=Summer, 3=Fall, 4=Winter)")
plt.ylabel("Jumlah Penyewaan")

plt.show()
# Out:
# C:\Users\asusn\AppData\Local\Temp\ipykernel_32424\627688400.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='season', y='cnt', data=day_df, palette='coolwarm')

# %% [markdown]
# ### Insight:
# Visualisasi menunjukkan bahwa musim dingin (season = 4) memiliki rata-rata penyewaan sepeda paling rendah dibandingkan musim lainnya.
#
# Sebaliknya, musim panas dan gugur memiliki jumlah penyewaan yang lebih tinggi. Hal ini mengindikasikan bahwa kondisi cuaca yang lebih hangat dan nyaman meningkatkan minat masyarakat untuk menggunakan sepeda.
#
# Dengan demikian, faktor musim terbukti memiliki pengaruh signifikan terhadap penurunan jumlah penyewaan sepeda.

# %% [markdown]
# ### Pertanyaan 2:

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=hour_df, x='hr', y='cnt', hue='weathersit', palette='Set2')

plt.title("Pola Penyewaan Sepeda Berdasarkan Jam dan Kondisi Cuaca", fontsize=14)
plt.xlabel("Jam")
plt.ylabel("Jumlah Penyewaan")

plt.show()

# %% [markdown]
# ### Insight:
# Terlihat adanya lonjakan penyewaan sepeda pada jam sibuk, yaitu sekitar pukul 08.00 dan 17.00.
#
# Hal ini menunjukkan pola commuting, di mana sepeda digunakan untuk berangkat dan pulang kerja.
#
# Namun, kondisi cuaca buruk (weathersit tinggi) menyebabkan penurunan signifikan dalam jumlah penyewaan, bahkan pada jam sibuk.
#
# Artinya, meskipun waktu berpengaruh, faktor cuaca tetap menjadi faktor dominan dalam menentukan jumlah pengguna.

# %% [markdown]
# # BOXPLOT MUSIM

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='season', y='cnt', data=day_df, palette='pastel')

plt.title("Distribusi Penyewaan Sepeda per Musim")
plt.show()
# Out:
# C:\Users\asusn\AppData\Local\Temp\ipykernel_32424\2724674141.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='season', y='cnt', data=day_df, palette='pastel')

# %% [markdown]
# ###  Insight:
# Distribusi menunjukkan bahwa musim dingin tidak hanya memiliki rata-rata rendah, tetapi juga variasi penyewaan yang lebih kecil.
#
# Hal ini menunjukkan bahwa penggunaan sepeda pada musim dingin cenderung konsisten rendah.

# %% [markdown]
# # WEATHER IMPACT

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='weathersit', y='cnt', data=day_df, palette='viridis')

plt.title("Pengaruh Kondisi Cuaca terhadap Penyewaan Sepeda")
plt.show()
# Out:
# C:\Users\asusn\AppData\Local\Temp\ipykernel_32424\4054673791.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='weathersit', y='cnt', data=day_df, palette='viridis')

# %% [markdown]
# ### Insight:
# Kondisi cuaca yang semakin buruk (nilai weathersit lebih tinggi) secara konsisten menurunkan jumlah penyewaan sepeda.
#
# Hal ini menunjukkan bahwa cuaca merupakan faktor eksternal yang sangat berpengaruh terhadap perilaku pengguna.

# %% [markdown]
# ## Advanced Analysis: RFM Analysis
#
# RFM Analysis digunakan untuk menganalisis perilaku pengguna berdasarkan tiga aspek utama:
#
# - **Recency**: Seberapa baru aktivitas terakhir terjadi
# - **Frequency**: Seberapa sering aktivitas dilakukan
# - **Monetary**: Seberapa besar nilai aktivitas
#
# Pada dataset ini, karena tidak terdapat data pelanggan individu, maka pendekatan RFM dilakukan dengan menggunakan agregasi berbasis tanggal (dteday) sebagai representasi aktivitas pengguna.

# %%
# Pastikan datetime
day_df['dteday'] = pd.to_datetime(day_df['dteday'])

# Hitung Recency (hari sejak terakhir aktivitas)
latest_date = day_df['dteday'].max()

rfm = day_df.groupby('dteday').agg({
    'cnt': ['sum','count']
}).reset_index()

rfm.columns = ['dteday','monetary','frequency']

# Recency
rfm['recency'] = (latest_date - rfm['dteday']).dt.days

rfm.head()
# Out:
#       dteday  monetary  frequency  recency
# 0 2011-01-01       985          1      730
# 1 2011-01-02       801          1      729
# 2 2011-01-03      1349          1      728
# 3 2011-01-04      1562          1      727
# 4 2011-01-05      1600          1      726

# %% [markdown]
# # SCORING RFM

# %%
# Binning / scoring
rfm['R_score'] = pd.qcut(rfm['recency'], 3, labels=[3,2,1])
rfm['F_score'] = pd.cut(rfm['frequency'], bins=3, labels=[1,2,3])
rfm['M_score'] = pd.qcut(rfm['monetary'], 3, labels=[1,2,3])

# Gabungkan
rfm['RFM_score'] = (
    rfm['R_score'].astype(str) +
    rfm['F_score'].astype(str) +
    rfm['M_score'].astype(str)
)

rfm.head()
# Out:
#       dteday  monetary  frequency  recency R_score F_score M_score RFM_score
# 0 2011-01-01       985          1      730       1       2       1       121
# 1 2011-01-02       801          1      729       1       2       1       121
# 2 2011-01-03      1349          1      728       1       2       1       121
# 3 2011-01-04      1562          1      727       1       2       1       121
# 4 2011-01-05      1600          1      726       1       2       1       121

# %% [markdown]
# # SEGMENTASI (CLUSTERING SEDERHANA)

# %%
def segment(row):
    if row['RFM_score'] == '333':
        return 'High Activity'
    elif row['RFM_score'][0] == '3':
        return 'Recent Users'
    elif row['RFM_score'][1] == '3':
        return 'Frequent Users'
    else:
        return 'Low Activity'

rfm['segment'] = rfm.apply(segment, axis=1)

rfm.head()
# Out:
#       dteday  monetary  frequency  recency R_score F_score M_score RFM_score  \
# 0 2011-01-01       985          1      730       1       2       1       121
# 1 2011-01-02       801          1      729       1       2       1       121
# 2 2011-01-03      1349          1      728       1       2       1       121
# 3 2011-01-04      1562          1      727       1       2       1       121
# 4 2011-01-05      1600          1      726       1       2       1       121
#
#         segment
# 0  Low Activity
# 1  Low Activity
# 2  Low Activity
# 3  Low Activity
# 4  Low Activity

# %% [markdown]
# # VISUALISASI SEGMENTASI

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='segment', data=rfm, palette='Set2')

plt.title("Distribusi Segmentasi Aktivitas Pengguna")
plt.show()
# Out:
# C:\Users\asusn\AppData\Local\Temp\ipykernel_32424\3884220717.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='segment', data=rfm, palette='Set2')

# %% [markdown]
# ### Insight RFM:
#
# Hasil segmentasi menunjukkan adanya variasi tingkat aktivitas pengguna berdasarkan waktu.
#
# Kelompok **High Activity** menunjukkan periode dengan penggunaan sepeda yang tinggi dan konsisten, sedangkan kelompok **Low Activity** menunjukkan periode dengan penggunaan yang rendah.
#
# Segmentasi ini dapat digunakan untuk:
# - Mengidentifikasi periode peak usage
# - Menentukan strategi promosi pada periode rendah
# - Mengoptimalkan distribusi sepeda

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# #  Conclusion
#
# -  Kesimpulan Pertanyaan 1
#    Faktor musim memiliki pengaruh signifikan terhadap jumlah penyewaan sepeda. Berdasarkan hasil analisis, musim dingin menunjukkan jumlah penyewaan paling rendah dibandingkan musim lainnya.
#
# Hal ini disebabkan oleh kondisi cuaca yang kurang mendukung seperti suhu rendah dan kemungkinan kondisi lingkungan yang tidak nyaman untuk bersepeda.
#
#
# -  Kesimpulan Pertanyaan 2
#    Pola penggunaan sepeda menunjukkan adanya lonjakan pada jam sibuk, yaitu sekitar pukul 08.00 dan 17.00. Hal ini mengindikasikan bahwa sepeda banyak digunakan untuk aktivitas commuting.
#
# Namun, kondisi cuaca terbukti memiliki pengaruh yang kuat, di mana cuaca buruk secara signifikan menurunkan jumlah penyewaan, bahkan pada jam sibuk.
#
#
# -  Kesimpulan Tambahan (Advanced Analysis)
#    Hasil RFM Analysis menunjukkan adanya perbedaan tingkat aktivitas berdasarkan waktu.
#
# Terdapat periode dengan aktivitas tinggi (High Activity) dan periode dengan aktivitas rendah (Low Activity), yang dapat digunakan untuk memahami pola penggunaan sepeda secara lebih mendalam.

# %% [markdown]
# #  Recommendation
#
# Berdasarkan hasil analisis yang telah dilakukan, berikut beberapa rekomendasi yang dapat diterapkan:
#
#  1. Strategi Musim (Season-Based Strategy)
# Memberikan promosi atau insentif pada musim dingin untuk meningkatkan minat pengguna, seperti diskon atau program loyalitas.
#
#
#  2. Optimasi Jam Sibuk (Peak Hour Optimization)
# Menambah jumlah sepeda dan memastikan ketersediaan unit pada jam sibuk (pagi dan sore) untuk mengakomodasi kebutuhan pengguna.
#
#  3. Integrasi Data Cuaca
# Menggunakan data cuaca untuk memprediksi permintaan penyewaan sepeda dan menyesuaikan distribusi sepeda secara dinamis.
#
#
#  4. Strategi Berdasarkan Segmentasi (RFM)
# Memanfaatkan hasil segmentasi untuk:
# - Mengidentifikasi periode dengan aktivitas tinggi
# - Menargetkan promosi pada periode dengan aktivitas rendah
# - Mengoptimalkan operasional berdasarkan pola penggunaan

# %% [markdown]
# ##  Penutup
#
# Secara keseluruhan, analisis ini menunjukkan bahwa faktor musim, waktu, dan kondisi cuaca memiliki pengaruh signifikan terhadap pola penggunaan sepeda.
#
# Dengan memanfaatkan insight yang diperoleh, perusahaan dapat meningkatkan efisiensi operasional serta mengoptimalkan strategi bisnis untuk meningkatkan jumlah pengguna.

# %%
day_df.to_csv("dashboard/main_data.csv", index=False)
